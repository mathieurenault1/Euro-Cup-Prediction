# %%
import pandas as pd
import numpy as np
playerdata = pd.read_csv('C:/Users/Admin/Desktop/data/finaldata16.csv')
print(playerdata)
# Out:
#      Unnamed: 0      id          Fullname  current_rating  potential_rating  \
# 0           237   17725      Aaron Hughes              70                70
# 1          8583  186561      Aaron Ramsey              82                85
# 2          5891  180819      Adam Lallana              80                80
# 3          2983  223207         Ádám Lang              68                74
# 4         11133  230936         Ádám Nagy              68                79
# ..          ...     ...               ...             ...               ...
# 453       12828  173474  Zlatko Junuzović              78                78
# 454        1677  137089       Zoltán Gera              74                74
# 455        5632  179712    Zoltán Stieber              73                74
# 456        5726  164835  Łukasz Fabiański              78                78
# 457       13458  173771   Łukasz Piszczek              80                80
#
# ...

# %%
playerdata.drop(playerdata.columns[[0, 1]], inplace=True, axis=1)

# %%
mean = playerdata.groupby(['nationality']).mean()
mean
# Out:
#                      current_rating  potential_rating      height     weight  \
# nationality
# Albania                   69.166667         72.333333  179.916667  75.000000
# Austria                   74.333333         76.238095  185.238095  80.761905
# Belgium                   79.727273         82.045455  184.727273  78.772727
# Croatia                   78.562500         80.687500  183.750000  77.062500
# Czech Republic            73.761905         75.428571  184.190476  77.809524
# England                   78.833333         82.583333  183.041667  76.291667
# France                    81.045455         83.090909  181.954545  77.136364
# Germany                   81.652174         85.391304  185.956522  81.173913
# Hungary                   70.238095         72.428571  184.238095  79.047619
# Iceland                   68.277778         70.722222  185.444444  79.166667
# Italy                     80.217391         81.826087  183.347826  77.608696
# ...

# %%
median = playerdata.groupby(['nationality']).median()
median
# Out:
#                      current_rating  potential_rating  height  weight  \
# nationality
# Albania                        69.5              73.5   183.0    74.5
# Austria                        74.0              76.0   186.0    82.0
# Belgium                        80.0              82.0   185.0    80.0
# Croatia                        78.0              81.0   184.0    77.5
# Czech Republic                 74.0              75.0   183.0    77.0
# England                        79.5              84.0   183.5    74.0
# France                         81.0              83.0   181.0    75.5
# Germany                        82.0              87.0   186.0    82.0
# Hungary                        70.0              72.0   185.0    79.0
# Iceland                        68.0              70.0   187.0    79.5
# Italy                          79.0              82.0   185.0    79.0
# Northern Ireland               69.0              71.0   183.0    72.0
# ...

# %%
maximum = playerdata.groupby(['nationality']).max()
maximum#.max('current_rating')
# Out:
#                                  Fullname  current_rating  potential_rating  \
# nationality
# Albania                     Taulant Xhaka              77                81
# Austria                  Zlatko Junuzović              85                88
# Belgium                  Yannick Carrasco              88                90
# Croatia                     Šime Vrsaljko              87                87
# Czech Republic               Tomáš Vaclík              86                86
# England                      Wayne Rooney              85                89
# France                     Steve Mandanda              86                91
# Germany                        Toni Kroos              90                90
# Hungary                         Ákos Elek              78                79
# Iceland              Ögmundur Kristinsson              75                78
# Italy                        Thiago Motta              86                86
# ...

# %%
minimum = playerdata.groupby(['nationality']).min()
minimum#.min('current_rating')
# Out:
#                                 Fullname  current_rating  potential_rating  \
# nationality
# Albania                     Amir Abrashi              61                61
# Austria              Aleksandar Dragović              66                66
# Belgium                      Axel Witsel              72                73
# Croatia                  Andrej Kramarić              72                73
# Czech Republic              Bořek Dočkal              67                67
# England                     Adam Lallana              68                74
# France                         Adil Rami              77                78
# Germany                   André Schürrle              74                78
# Hungary                     Attila Fiola              63                68
# Iceland               Alfreð Finnbogason              59                61
# Italy                Alessandro Florenzi              75                77
# ...

# %%
Albania = playerdata.copy()
for i in range(len(Albania)):
    if Albania.loc[i,'nationality'] != 'Albania':
        Albania = Albania.drop([i], axis = 0)
Austria = playerdata.copy()
for i in range(len(Austria)):
    if Austria.loc[i,'nationality'] != 'Austria':
        Austria = Austria.drop([i], axis = 0)
Belgium = playerdata.copy()
for i in range(len(Belgium)):
    if Belgium.loc[i,'nationality'] != 'Belgium':
        Belgium = Belgium.drop([i], axis = 0)
Croatia = playerdata.copy()
for i in range(len(Croatia)):
    if Croatia.loc[i,'nationality'] != 'Croatia':
        Croatia = Croatia.drop([i], axis = 0)
CzechRepublic = playerdata.copy()
for i in range(len(CzechRepublic)):
    if CzechRepublic.loc[i,'nationality'] != 'CzechRepublic':
        CzechRepublic = CzechRepublic.drop([i], axis = 0)
England = playerdata.copy()
for i in range(len(England)):
    if England.loc[i,'nationality'] != 'England':
        England = England.drop([i], axis = 0)
France = playerdata.copy()
for i in range(len(France)):
    if France.loc[i,'nationality'] != 'France':
        France = France.drop([i], axis = 0)
Germany = playerdata.copy()
for i in range(len(Germany)):
    if Germany.loc[i,'nationality'] != 'Germany':
        Germany = Germany.drop([i], axis = 0)
Hungary = playerdata.copy()
for i in range(len(Hungary)):
    if Hungary.loc[i,'nationality'] != 'Hungary':
        Hungary = Hungary.drop([i], axis = 0)
Iceland = playerdata.copy()
for i in range(len(Iceland)):
    if Iceland.loc[i,'nationality'] != 'Iceland':
        Iceland = Iceland.drop([i], axis = 0)
Italy = playerdata.copy()
for i in range(len(Italy)):
    if Italy.loc[i,'nationality'] != 'Italy':
        Italy = Italy.drop([i], axis = 0)
NorthernIreland = playerdata.copy()
for i in range(len(NorthernIreland)):
    if NorthernIreland.loc[i,'nationality'] != 'NorthernIreland':
        NorthernIreland = NorthernIreland.drop([i], axis = 0)
Poland = playerdata.copy()
for i in range(len(Poland)):
    if Poland.loc[i,'nationality'] != 'Poland':
        Poland = Poland.drop([i], axis = 0)
Portugal = playerdata.copy()
for i in range(len(Portugal)):
    if Portugal.loc[i,'nationality'] != 'Portugal':
        Portugal = Portugal.drop([i], axis = 0)
RepublicofIreland = playerdata.copy()
for i in range(len(RepublicofIreland)):
    if RepublicofIreland.loc[i,'nationality'] != 'RepublicofIreland':
        RepublicofIreland = RepublicofIreland.drop([i], axis = 0)
Romania = playerdata.copy()
for i in range(len(Romania)):
    if Romania.loc[i,'nationality'] != 'Romania':
        Romania = Romania.drop([i], axis = 0)
Russia = playerdata.copy()
for i in range(len(Russia)):
    if Russia.loc[i,'nationality'] != 'Russia':
        Russia = Russia.drop([i], axis = 0)
Slovakia = playerdata.copy()
for i in range(len(Slovakia)):
    if Slovakia.loc[i,'nationality'] != 'Slovakia':
        Slovakia = Slovakia.drop([i], axis = 0)
Spain = playerdata.copy()
for i in range(len(Spain)):
    if Spain.loc[i,'nationality'] != 'Spain':
        Spain = Spain.drop([i], axis = 0)
Sweden = playerdata.copy()
for i in range(len(Sweden)):
    if Sweden.loc[i,'nationality'] != 'Sweden':
        Sweden = Sweden.drop([i], axis = 0)
Switzerland = playerdata.copy()
for i in range(len(Switzerland)):
    if Switzerland.loc[i,'nationality'] != 'Switzerland':
        Switzerland = Switzerland.drop([i], axis = 0)
Turkey = playerdata.copy()
for i in range(len(Turkey)):
    if Turkey.loc[i,'nationality'] != 'Turkey':
        Turkey = Turkey.drop([i], axis = 0)
Ukraine = playerdata.copy()
for i in range(len(Ukraine)):
    if Ukraine.loc[i,'nationality'] != 'Ukraine':
        Ukraine = Ukraine.drop([i], axis = 0)
Wales = playerdata.copy()
for i in range(len(Wales)):
    if Wales.loc[i,'nationality'] != 'Wales':
        Wales = Wales.drop([i], axis = 0)
