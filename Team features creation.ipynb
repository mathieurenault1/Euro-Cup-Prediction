# %%
import pandas as pd
import numpy as np
playerdata = pd.read_csv('C:/Users/Lerog/Documents/M1/Project 2/Euro-Cup-Prediction-main/FinalData/finaldata16.csv')
print(playerdata)
# Out:
#      Unnamed: 0      id          Fullname  current_rating  potential_rating  \
# 0           237   17725      Aaron Hughes              70                70
# 1          8583  186561      Aaron Ramsey              82                85
# 2          5891  180819      Adam Lallana              80                80
# 3          2983  223207         Ádám Lang              68                74
# 4         11133  230936         Ádám Nagy              68                79
# ..          ...     ...               ...             ...               ...
# 453       12828  173474  Zlatko Junuzović              78                78
# 454        1677  137089       Zoltán Gera              74                74
# 455        5632  179712    Zoltán Stieber              73                74
# 456        5726  164835  Łukasz Fabiański              78                78
# 457       13458  173771   Łukasz Piszczek              80                80
#
# ...

# %%
playerdata.drop(playerdata.columns[[0, 1]], inplace=True, axis=1)

# %%
mean = playerdata.groupby(['nationality']).mean()
mean
# Out:
#                      current_rating  potential_rating      height     weight  \
# nationality
# Albania                   69.166667         72.333333  179.916667  75.000000
# Austria                   74.333333         76.238095  185.238095  80.761905
# Belgium                   79.727273         82.045455  184.727273  78.772727
# Croatia                   78.562500         80.687500  183.750000  77.062500
# Czech Republic            73.761905         75.428571  184.190476  77.809524
# England                   78.833333         82.583333  183.041667  76.291667
# France                    81.045455         83.090909  181.954545  77.136364
# Germany                   81.652174         85.391304  185.956522  81.173913
# Hungary                   70.238095         72.428571  184.238095  79.047619
# Iceland                   68.277778         70.722222  185.444444  79.166667
# Italy                     80.217391         81.826087  183.347826  77.608696
# ...

# %%
median = playerdata.groupby(['nationality']).median()
median
# Out:
#                      current_rating  potential_rating  height  weight  \
# nationality
# Albania                        69.5              73.5   183.0    74.5
# Austria                        74.0              76.0   186.0    82.0
# Belgium                        80.0              82.0   185.0    80.0
# Croatia                        78.0              81.0   184.0    77.5
# Czech Republic                 74.0              75.0   183.0    77.0
# England                        79.5              84.0   183.5    74.0
# France                         81.0              83.0   181.0    75.5
# Germany                        82.0              87.0   186.0    82.0
# Hungary                        70.0              72.0   185.0    79.0
# Iceland                        68.0              70.0   187.0    79.5
# Italy                          79.0              82.0   185.0    79.0
# Northern Ireland               69.0              71.0   183.0    72.0
# ...

# %%
maximum = playerdata.groupby(['nationality'])
maximum.max('current_rating')
# Out:
#                      current_rating  potential_rating  height  weight  \
# nationality
# Albania                          77                81     194      92
# Austria                          85                88     196      93
# Belgium                          88                90     199      94
# Croatia                          87                87     192      85
# Czech Republic                   86                86     198      97
# England                          85                89     201      91
# France                           86                91     192      88
# Germany                          90                90     194      98
# Hungary                          78                79     193      91
# Iceland                          75                78     193      88
# Italy                            86                86     194      91
# Northern Ireland                 76                78     195      92
# ...

# %%
minimum = playerdata.groupby(['nationality'])
minimum.min('current_rating')
# Out:
#                      current_rating  potential_rating  height  weight  \
# nationality
# Albania                          61                61     161      58
# Austria                          66                66     172      69
# Belgium                          72                73     169      61
# Croatia                          72                73     174      65
# Czech Republic                   67                67     176      65
# England                          68                74     170      65
# France                           77                78     169      65
# Germany                          74                78     176      70
# Hungary                          63                68     173      67
# Iceland                          59                61     170      65
# Italy                            75                77     163      59
# Northern Ireland                 63                65     165      59
# ...

# %%
grouped=playerdata.groupby(['nationality'])
d = {}
for nat in playerdata['nationality']:
    d[nat] = pd.DataFrame()
print(d)
# Out:
# {'Northern Ireland': Empty DataFrame
# Columns: []
# Index: [], 'Wales': Empty DataFrame
# Columns: []
# Index: [], 'England': Empty DataFrame
# Columns: []
# Index: [], 'Hungary': Empty DataFrame
# Columns: []
# Index: [], 'Slovakia': Empty DataFrame
# Columns: []
# Index: [], 'France': Empty DataFrame
# Columns: []
# Index: [], 'Switzerland': Empty DataFrame
# Columns: []
# Index: [], 'Portugal': Empty DataFrame
# Columns: []
# Index: [], 'Turkey': Empty DataFrame
# Columns: []
# Index: [], 'Republic of Ireland': Empty DataFrame
# Columns: []
# Index: [], 'Sweden': Empty DataFrame
# Columns: []
# Index: [], 'Austria': Empty DataFrame
# Columns: []
# Index: [], 'Italy': Empty DataFrame
# Columns: []
# Index: [], 'Russia': Empty DataFrame
# Columns: []
# Index: [], 'Romania': Empty DataFrame
# Columns: []
# Index: [], 'Iceland': Empty DataFrame
# Columns: []
# Index: [], 'Albania': Empty DataFrame
# Columns: []
# Index: [], 'Germany': Empty DataFrame
# Columns: []
# ...
